# %%
import pylab as p, numpy as n, rdflib as r, networkx as x, string as s, nltk as k

# %%
p.plot(n.sin(n.arange(0,7,0.2)),"ro")

# %%
dom = k.Text(k.corpus.machado.words('romance/marm08.txt'), name="Dom Casmurro (1899)")

# %%
dom[:10]
# Out:
# [u'Romance', u',', u'Dom', u'Casmurro', u',', u'1899', u'Dom', u'Casmurro', u'Texto', u'de']

# %%
dom.dispersion_plot([u"casmurro", u"dom",       "Bento","bento","Santiago","Capitu","Machado","machado",        "feminino","masculino","homem","mulher",u"pá","martelo","livro","caneta",       "bem","mal","bom","ruim",u"saúde",u"doença","cura",        "feio","bonito","bonita"]);

# %% [markdown]
# ### Machado não usa fruta alguma (dentre as buscadas) no Dom Casmurro. Das vestimentas comuns consideradas, escreve somente uma vez camisa:### Usa bastante partes do corpo

# %%
dom.dispersion_plot(["banana",u"maçã",u"pêra","uva",u"mamão","abacate", "morango","melancia",u"melão",                     "camisa",u"calça","shorts",u"calção","cueca","calcinha",u"sutiã",                     u"cabeça", u"mão",u"pé","perna",u"braço","olho","boca","nariz",])
